# %%
import requests
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import requests

api_key = 'chh7nspr01qqda68rnegchh7nspr01qqda68rnf0'
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=' + api_key
r = requests.get(url)
data = r.json()

# %%
closing_prices = list(
    map(
        lambda x : float(x['4. close']), list(data['Time Series (5min)'].values())
    )
)

# %%
fig, ax = plt.subplots(figsize=(10,10))
plt.plot(closing_prices)

plt.xlabel('Minutes')
plt.ylabel('Closing Price')
plt.title('Microsoft Corporation Stock Price')

plt.yticks(np.arange(min(closing_prices), max(closing_prices)+0.05, 0.05))

plt.show()
